# %% [markdown]
# # Project 2

# %%
import pandas as pd   # to load and transform data
import numpy as np    # for math/stat calculations
import altair as alt
import json

# %%
# load flights data
flight_url = 'https://raw.githubusercontent.com/byuidatascience/data4missing/master/data-raw/flights_missing/flights_missing.json'
flights = pd.read_json(flight_url)
flights.head()
# Out:
#   airport_code                                       airport_name    month  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  January
# 1          DEN                   Denver, CO: Denver International  January
# 2          IAD                                                     January
# 3          ORD          Chicago, IL: Chicago O'Hare International  January
# 4          SAN             San Diego, CA: San Diego International  January
#
#      year  num_of_flights_total num_of_delays_carrier  \
# 0  2005.0                 35048                 1500+
# 1  2005.0                 12687                  1041
# 2  2005.0                 12381                   414
# 3  2005.0                 28194                  1197
# 4  2005.0                  7283                   572
#
#    num_of_delays_late_aircraft  num_of_delays_nas  num_of_delays_security  \
# 0                         -999               4598                      10
# 1                          928                935                      11
# 2                         1058                895                       4
# 3                         2255               5415                       5
# 4                          680                638                       7
#
#    num_of_delays_weather  num_of_delays_total  minutes_delayed_carrier  \
# 0                    448                 8355                 116423.0
# 1                    233                 3153                  53537.0
# 2                     61                 2430                      NaN
# 3                    306                 9178                  88691.0
# 4                     56                 1952                  27436.0
#
#    minutes_delayed_late_aircraft  minutes_delayed_nas  \
# 0                         104415             207467.0
# 1                          70301              36817.0
# 2                          70919              35660.0
# 3                         160811             364382.0
# 4                          38445              21127.0
#
#    minutes_delayed_security  minutes_delayed_weather  minutes_delayed_total
# 0                       297                    36931                 465533
# 1                       363                    21779                 182797
# 2                       208                     4497                 134881
# 3                       151                    24859                 638894
# 4                       218                     4326                  91552

# %% [markdown]
# ## Question 1

# %%
# average of minutes_delayed_total for each airport
q1_table = (flights
    .groupby('airport_code')
    .agg(total_flights = ('num_of_flights_total', sum),
        total_delays = ('num_of_delays_total', sum),
        total_delay_min = ('minutes_delayed_total', sum),
        )
    .assign(prop_delays = lambda x: x.total_delays / x.total_flights,
            avg_delay_hrs = lambda x: x.total_delay_min / x.total_delays / 60
            )
    .reset_index()
)

# print makes table more organized 
# index=False gets rid of index column 
print(q1_table.to_markdown(index=False))
# Out:
# | airport_code   |   total_flights |   total_delays |   total_delay_min |   prop_delays |   avg_delay_hrs |
# |:---------------|----------------:|---------------:|------------------:|--------------:|----------------:|
# | ATL            |         4430047 |         902443 |          53983926 |      0.20371  |        0.996996 |
# | DEN            |         2513974 |         468519 |          25173381 |      0.186366 |        0.895495 |
# | IAD            |          851571 |         168467 |          10283478 |      0.197831 |        1.01736  |
# | ORD            |         3597588 |         830825 |          56356129 |      0.230939 |        1.13053  |
# | SAN            |          917862 |         175132 |           8276248 |      0.190804 |        0.78762  |
# | SFO            |         1630945 |         425604 |          26550493 |      0.260955 |        1.03972  |
# | SLC            |         1403384 |         205160 |          10123371 |      0.146189 |        0.822396 |

# %%
# find max aver delay hrs for airport code
highest_delay_avg = max(q1_table.avg_delay_hrs)
print(highest_delay_avg)
# Out:
# 1.130525461639535

# %%
# create new table so can edit data
delay_dif_table = q1_table
# replace highest value with nan
delay_dif_table.avg_delay_hrs.replace(highest_delay_avg, np.nan, inplace=True)
# print(delay_dif_table)
# find difference between ORD avg and all other airports
delay_dif = delay_dif_table.avg_delay_hrs - highest_delay_avg
avg_dif = delay_dif.mean()
print(avg_dif)
# Out:
# -0.20392816278753778

# %%
# worst weather delay
q1_weather = (flights
    .groupby('airport_code')
    .agg(total_delay_weather = ('num_of_delays_weather', sum)
        )
    .assign()
    .reset_index()
)

print(q1_weather.to_markdown(index=False))
print(max(q1_weather.total_delay_weather))
# Out:
# | airport_code   |   total_delay_weather |
# |:---------------|----------------------:|
# | ATL            |                 32375 |
# | DEN            |                 13836 |
# | IAD            |                  4794 |
# | ORD            |                 20765 |
# | SAN            |                  4320 |
# | SFO            |                 10377 |
# | SLC            |                  6831 |
# 32375

# %% [markdown]
# ## Question 2

# %%
# fill in na months
# should've worked but didn't
# flights.month.replace('n/a', np.nan)
# flights.month.fillna(method='bfill')
# mdata = flights
# mdata.month.replace('n/a', np.nan).fillna(method='bfill', inplace=True)
mdata = flights.query('month != "n/a"')

# %%
mdata.month.value_counts(dropna=False)
# Out:
# April        77
# July         77
# October      77
# Febuary      76
# November     76
# June         75
# August       75
# September    74
# January      73
# May          73
# December     73
# March        71
# Name: month, dtype: int64

# %%
q2_table = (mdata
    .groupby('month')
    .agg(total_flights = ('num_of_flights_total', sum),
        total_delays = ('num_of_delays_total', sum),
        total_delay_min = ('minutes_delayed_total', sum),
        # av_delay_mins = ('minutes_delayed_total', 'mean')
        )
    .assign(prop_delays = lambda x: x.total_delays / x.total_flights,
            avg_delay_hrs = lambda x: x.total_delay_min / x.total_delays / 60
            )
    .reset_index()
)

# print makes table more organized 
# index=False gets rid of index column 
print(q2_table.to_markdown(index=False))
# Out:
# | month     |   total_flights |   total_delays |   total_delay_min |   prop_delays |   avg_delay_hrs |
# |:----------|----------------:|---------------:|------------------:|--------------:|----------------:|
# | April     |         1259723 |         231408 |          13667654 |      0.183698 |        0.984384 |
# | August    |         1335158 |         279699 |          16906565 |      0.209488 |        1.00743  |
# | December  |         1180278 |         303133 |          18821267 |      0.256832 |        1.03482  |
# | Febuary   |         1115814 |         248033 |          14753955 |      0.222289 |        0.991397 |
# | January   |         1193018 |         265001 |          16152667 |      0.222127 |        1.01589  |
# | July      |         1371741 |         319960 |          20465456 |      0.233251 |        1.06604  |
# | June      |         1305663 |         317895 |          20338750 |      0.243474 |        1.06632  |
# | March     |         1213370 |         250142 |          14942262 |      0.206155 |        0.995585 |
# | May       |         1227795 |         233494 |          13637705 |      0.190173 |        0.973451 |
# | November  |         1185434 |         197768 |          11112089 |      0.166832 |        0.936458 |
# | October   |         1301612 |         235166 |          13109792 |      0.180673 |        0.929116 |
# | September |         1227208 |         201905 |          11495811 |      0.164524 |        0.948946 |

# %%
# chart code from q1
q2_chart = (alt.Chart(q2_table)
    .mark_bar(color='green', opacity=0.6)
    .encode(
        x = alt.X('total_delays', axis=alt.Axis(title = 'Total Delays')), 
        y = alt.Y('month', axis=alt.Axis(title='Month'), sort=['January', 'Febuary', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']))
    .properties(width=400,
                title= {'text': 'Total Delays', 'subtitle': 'Amount of delays by month'}
                )
    )
q2_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Question 3

# %%
flights.num_of_delays_weather.value_counts(dropna=False)
# Out:
# 27     17
# 20     15
# 15     14
# 37     14
# 34     13
#        ..
# 243     1
# 173     1
# 712     1
# 233     1
# 152     1
# Name: num_of_delays_weather, Length: 269, dtype: int64

# %%
# make copy of data so don't mess it up/change OG data
q3_data = flights

# replace -999 with NaN
q3_data.num_of_delays_late_aircraft.replace(-999, np.nan, inplace=True)

# find mean of data
late_delay_mean = q3_data.num_of_delays_late_aircraft.mean()

# replace NaN data with the mean
new_data = q3_data.num_of_delays_late_aircraft.fillna(value=late_delay_mean, inplace=True)

weather = q3_data.assign(
    severe = q3_data.num_of_delays_weather,
    mild_late = 0.3*q3_data.num_of_delays_late_aircraft,
    mild_nas = np.where(q3_data.month.isin(['April', 'May', 'June', 'July', 'August']), 
                0.4*q3_data.num_of_delays_nas,
                0.65*q3_data.num_of_delays_nas),
    total = lambda x: x.severe + x.mild_late + x.mild_nas
)

# average of minutes_delayed_total for each airport
q3_table = (weather
    .groupby('airport_code')
    .agg(total_weather_delays = ('total', sum),
        total_flights = ('num_of_flights_total', sum),
        severe = ('severe', sum),
        mild_late = ('mild_late', sum),
        mild_nas = ('mild_nas', sum)
        )
    .assign(percent_delay_weather = lambda x: x.total_weather_delays / x.total_flights * 100)
    .sort_values(by = 'percent_delay_weather', ascending = False)
    .reset_index()
)

# print makes table more organized 
# index=False gets rid of index column 
print(q3_table.to_markdown())
# Out:
# |    | airport_code   |   total_weather_delays |   total_flights |   severe |   mild_late |   mild_nas |   percent_delay_weather |
# |---:|:---------------|-----------------------:|----------------:|---------:|------------:|-----------:|------------------------:|
# |  0 | SFO            |               159594   |         1630945 |    10377 |     37251   |   111966   |                 9.78535 |
# |  1 | ORD            |               309954   |         3597588 |    20765 |     81045.1 |   208144   |                 8.61561 |
# |  2 | ATL            |               314801   |         4430047 |    32375 |     70680.5 |   211745   |                 7.10603 |
# |  3 | IAD            |                50842.7 |          851571 |     4794 |     19451.1 |    26597.5 |                 5.97045 |
# |  4 | DEN            |               149107   |         2513974 |    13836 |     54000.3 |    81270.7 |                 5.93113 |
# |  5 | SAN            |                48920.6 |          917862 |     4320 |     21180.3 |    23420.2 |                 5.32984 |
# |  6 | SLC            |                60345.8 |         1403384 |     6831 |     23835.3 |    29679.5 |                 4.30002 |

# %% [markdown]
# ## Question 4

# %%
(alt.Chart(q3_table)
    .mark_bar(color='#98AC5D', opacity=0.8)
    .encode(x = alt.X('total_weather_delays', axis=alt.Axis(title='Total Weather Delays')),
        y = alt.Y('airport_code', axis=alt.Axis(title='Airport Code'))
        )
    .properties(
        height = 250,
        width = 500,
        title = {'text': 'Total Weather Delays', 'subtitle': 'Mild to Severe'}
    )    
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Data That is Missing/Incorrect

# %%
# create new variable for data
updated_data = flights
updated_data.head(100)
# Out:
#    airport_code                                       airport_name    month  \
# 0           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  January
# 1           DEN                   Denver, CO: Denver International  January
# 2           IAD                                                     January
# 3           ORD          Chicago, IL: Chicago O'Hare International  January
# 4           SAN             San Diego, CA: San Diego International  January
# ..          ...                                                ...      ...
# 95          SAN             San Diego, CA: San Diego International  Febuary
# 96          SFO     San Francisco, CA: San Francisco International  Febuary
# 97          SLC   Salt Lake City, UT: Salt Lake City International  Febuary
# 98          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    March
# 99          DEN                   Denver, CO: Denver International    March
#
#       year  num_of_flights_total num_of_delays_carrier  \
# 0   2005.0                 35048                 1500+
# 1   2005.0                 12687                  1041
# 2   2005.0                 12381                   414
# 3   2005.0                 28194                  1197
# 4   2005.0                  7283                   572
# ..     ...                   ...                   ...
# 95  2006.0                  6962                   520
# 96  2006.0                  9742                   757
# 97  2006.0                 10375                   789
# 98  2006.0                 34988                 1500+
# 99  2006.0                 19193                  1331
#
#     num_of_delays_late_aircraft  num_of_delays_nas  num_of_delays_security  \
# 0                   1109.104072               4598                      10
# 1                    928.000000                935                      11
# 2                   1058.000000                895                       4
# 3                   2255.000000               5415                       5
# 4                    680.000000                638                       7
# ..                          ...                ...                     ...
# 95                   584.000000                558                       6
# 96                   645.000000               1573                       4
# 97                   626.000000                675                      16
# 98                  1596.000000               4458                      13
# 99                  1743.000000               1369                       5
#
#     num_of_delays_weather  num_of_delays_total  minutes_delayed_carrier  \
# 0                     448                 8355                 116423.0
# 1                     233                 3153                  53537.0
# 2                      61                 2430                      NaN
# 3                     306                 9178                  88691.0
# 4                      56                 1952                  27436.0
# ..                    ...                  ...                      ...
# 95                     72                 1740                  22801.0
# 96                     66                 3048                      NaN
# 97                     96                 2200                  35886.0
# 98                    286                 7870                  92476.0
# 99                    172                 4622                  64958.0
#
#     minutes_delayed_late_aircraft  minutes_delayed_nas  \
# 0                          104415             207467.0
# 1                           70301              36817.0
# 2                           70919              35660.0
# 3                          160811             364382.0
# 4                           38445              21127.0
# ..                            ...                  ...
# 95                          30032              22548.0
# 96                          40924                  NaN
# 97                          31434              21827.0
# 98                          82823             194182.0
# 99                         112207              47796.0
#
#     minutes_delayed_security  minutes_delayed_weather  minutes_delayed_total
# 0                        297                    36931                 465533
# 1                        363                    21779                 182797
# 2                        208                     4497                 134881
# 3                        151                    24859                 638894
# 4                        218                     4326                  91552
# ..                       ...                      ...                    ...
# 95                       147                     4974                  80502
# 96                       191                     4435                 161355
# 97                       587                     5123                  94857
# 98                      1024                    15803                 386308
# 99                       122                    13720                 238803
#
# [100 rows x 17 columns]

# %%
# tried to fill in missing airport name with their airport code 
# for i in updated_data:
#     if updated_data.airport_name == updated_data.airport_name.empty:
#         updated_data.airport_name.replace(updated_data.airport_name.empty, updated_data.airport_code[i])
#     i += 1

# %%
# replace 1500+ string with number
updated_data.num_of_delays_carrier.replace('1500+', 1500)
# Out:
# 0      1500
# 1      1041
# 2       414
# 3      1197
# 4       572
#        ...
# 919     182
# 920     923
# 921     480
# 922     757
# 923     483
# Name: num_of_delays_carrier, Length: 924, dtype: object

# %%
# fill in missing months
updated_data.month.replace('n/a', np.nan).fillna(method='bfill')
# Out:
# 0       January
# 1       January
# 2       January
# 3       January
# 4       January
#          ...
# 919    December
# 920    December
# 921    December
# 922    December
# 923    December
# Name: month, Length: 924, dtype: object

# %%
# replace nan for num_of_delays_late_aircraft
# replace -999 with NaN
updated_data.num_of_delays_late_aircraft.replace(-999, np.nan, inplace=True)

# find mean of data
late_delay_mean = updated_data.num_of_delays_late_aircraft.mean()

# replace NaN data with the mean
new_data = updated_data.num_of_delays_late_aircraft.replace(np.nan, late_delay_mean, inplace=True)
updated_data.head()
# Out:
#   airport_code                                       airport_name    month  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  January
# 1          DEN                   Denver, CO: Denver International  January
# 2          IAD                                                     January
# 3          ORD          Chicago, IL: Chicago O'Hare International  January
# 4          SAN             San Diego, CA: San Diego International  January
#
#      year  num_of_flights_total num_of_delays_carrier  \
# 0  2005.0                 35048                 1500+
# 1  2005.0                 12687                  1041
# 2  2005.0                 12381                   414
# 3  2005.0                 28194                  1197
# 4  2005.0                  7283                   572
#
#    num_of_delays_late_aircraft  num_of_delays_nas  num_of_delays_security  \
# 0                  1109.104072               4598                      10
# 1                   928.000000                935                      11
# 2                  1058.000000                895                       4
# 3                  2255.000000               5415                       5
# 4                   680.000000                638                       7
#
#    num_of_delays_weather  num_of_delays_total  minutes_delayed_carrier  \
# 0                    448                 8355                 116423.0
# 1                    233                 3153                  53537.0
# 2                     61                 2430                      NaN
# 3                    306                 9178                  88691.0
# 4                     56                 1952                  27436.0
#
#    minutes_delayed_late_aircraft  minutes_delayed_nas  \
# 0                         104415             207467.0
# 1                          70301              36817.0
# 2                          70919              35660.0
# 3                         160811             364382.0
# 4                          38445              21127.0
#
#    minutes_delayed_security  minutes_delayed_weather  minutes_delayed_total
# 0                       297                    36931                 465533
# 1                       363                    21779                 182797
# 2                       208                     4497                 134881
# 3                       151                    24859                 638894
# 4                       218                     4326                  91552

# %%
# replace nan for minutes_delayed_carrier
# find mean of data
delay_mean = updated_data.minutes_delayed_carrier.mean()

# replace NaN data with the mean
new_data = updated_data.minutes_delayed_carrier.replace(np.nan, delay_mean, inplace=True)
updated_data.head()
# Out:
#   airport_code                                       airport_name    month  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...  January
# 1          DEN                   Denver, CO: Denver International  January
# 2          IAD                                                     January
# 3          ORD          Chicago, IL: Chicago O'Hare International  January
# 4          SAN             San Diego, CA: San Diego International  January
#
#      year  num_of_flights_total num_of_delays_carrier  \
# 0  2005.0                 35048                 1500+
# 1  2005.0                 12687                  1041
# 2  2005.0                 12381                   414
# 3  2005.0                 28194                  1197
# 4  2005.0                  7283                   572
#
#    num_of_delays_late_aircraft  num_of_delays_nas  num_of_delays_security  \
# 0                  1109.104072               4598                      10
# 1                   928.000000                935                      11
# 2                  1058.000000                895                       4
# 3                  2255.000000               5415                       5
# 4                   680.000000                638                       7
#
#    num_of_delays_weather  num_of_delays_total  minutes_delayed_carrier  \
# 0                    448                 8355             116423.00000
# 1                    233                 3153              53537.00000
# 2                     61                 2430              51902.25344
# 3                    306                 9178              88691.00000
# 4                     56                 1952              27436.00000
#
#    minutes_delayed_late_aircraft  minutes_delayed_nas  \
# 0                         104415             207467.0
# 1                          70301              36817.0
# 2                          70919              35660.0
# 3                         160811             364382.0
# 4                          38445              21127.0
#
#    minutes_delayed_security  minutes_delayed_weather  minutes_delayed_total
# 0                       297                    36931                 465533
# 1                       363                    21779                 182797
# 2                       208                     4497                 134881
# 3                       151                    24859                 638894
# 4                       218                     4326                  91552

# %%
# json_data = updated_data.to_json()
# json_data

# by "record" or "row"
json_data = flights.to_json(orient="records")
json_object = json.loads(json_data)
json_formatted_str = json.dumps(json_object, indent = 4)
print(json_formatted_str)
# Out:
# [
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 35048,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 4598,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 448,
#         "num_of_delays_total": 8355,
#         "minutes_delayed_carrier": 116423.0,
#         "minutes_delayed_late_aircraft": 104415,
#         "minutes_delayed_nas": 207467.0,
#         "minutes_delayed_security": 297,
#         "minutes_delayed_weather": 36931,
#         "minutes_delayed_total": 465533
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 12687,
#         "num_of_delays_carrier": "1041",
#         "num_of_delays_late_aircraft": 928.0,
#         "num_of_delays_nas": 935,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 233,
#         "num_of_delays_total": 3153,
#         "minutes_delayed_carrier": 53537.0,
#         "minutes_delayed_late_aircraft": 70301,
#         "minutes_delayed_nas": 36817.0,
#         "minutes_delayed_security": 363,
#         "minutes_delayed_weather": 21779,
#         "minutes_delayed_total": 182797
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 12381,
#         "num_of_delays_carrier": "414",
#         "num_of_delays_late_aircraft": 1058.0,
#         "num_of_delays_nas": 895,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 61,
#         "num_of_delays_total": 2430,
#         "minutes_delayed_carrier": 51902.253440367,
#         "minutes_delayed_late_aircraft": 70919,
#         "minutes_delayed_nas": 35660.0,
#         "minutes_delayed_security": 208,
#         "minutes_delayed_weather": 4497,
#         "minutes_delayed_total": 134881
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 28194,
#         "num_of_delays_carrier": "1197",
#         "num_of_delays_late_aircraft": 2255.0,
#         "num_of_delays_nas": 5415,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 306,
#         "num_of_delays_total": 9178,
#         "minutes_delayed_carrier": 88691.0,
#         "minutes_delayed_late_aircraft": 160811,
#         "minutes_delayed_nas": 364382.0,
#         "minutes_delayed_security": 151,
#         "minutes_delayed_weather": 24859,
#         "minutes_delayed_total": 638894
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 7283,
#         "num_of_delays_carrier": "572",
#         "num_of_delays_late_aircraft": 680.0,
#         "num_of_delays_nas": 638,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 56,
#         "num_of_delays_total": 1952,
#         "minutes_delayed_carrier": 27436.0,
#         "minutes_delayed_late_aircraft": 38445,
#         "minutes_delayed_nas": 21127.0,
#         "minutes_delayed_security": 218,
#         "minutes_delayed_weather": 4326,
#         "minutes_delayed_total": 91552
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 10274,
#         "num_of_delays_carrier": "798",
#         "num_of_delays_late_aircraft": 733.0,
#         "num_of_delays_nas": 1166,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 114,
#         "num_of_delays_total": 2816,
#         "minutes_delayed_carrier": 41570.0,
#         "minutes_delayed_late_aircraft": 47705,
#         "minutes_delayed_nas": 60380.0,
#         "minutes_delayed_security": 247,
#         "minutes_delayed_weather": 7373,
#         "minutes_delayed_total": 157275
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "January",
#         "year": 2005.0,
#         "num_of_flights_total": 12000,
#         "num_of_delays_carrier": "817",
#         "num_of_delays_late_aircraft": 564.0,
#         "num_of_delays_nas": 864,
#         "num_of_delays_security": 13,
#         "num_of_delays_weather": 270,
#         "num_of_delays_total": 2525,
#         "minutes_delayed_carrier": 36252.0,
#         "minutes_delayed_late_aircraft": 30557,
#         "minutes_delayed_nas": 35977.0,
#         "minutes_delayed_security": 327,
#         "minutes_delayed_weather": 27219,
#         "minutes_delayed_total": 130332
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 33702,
#         "num_of_delays_carrier": "1288",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 6104,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 399,
#         "num_of_delays_total": 9195,
#         "minutes_delayed_carrier": 86876.0,
#         "minutes_delayed_late_aircraft": 86698,
#         "minutes_delayed_nas": 321969.0,
#         "minutes_delayed_security": 36,
#         "minutes_delayed_weather": 31944,
#         "minutes_delayed_total": 527523
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 11480,
#         "num_of_delays_carrier": "729",
#         "num_of_delays_late_aircraft": 432.0,
#         "num_of_delays_nas": 581,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 42,
#         "num_of_delays_total": 1788,
#         "minutes_delayed_carrier": 33205.0,
#         "minutes_delayed_late_aircraft": 26228,
#         "minutes_delayed_nas": 16864.0,
#         "minutes_delayed_security": 271,
#         "minutes_delayed_weather": 2781,
#         "minutes_delayed_total": 79349
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 10042,
#         "num_of_delays_carrier": "284",
#         "num_of_delays_late_aircraft": 631.0,
#         "num_of_delays_nas": 691,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 28,
#         "num_of_delays_total": 1639,
#         "minutes_delayed_carrier": 15573.0,
#         "minutes_delayed_late_aircraft": 39840,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 169,
#         "minutes_delayed_weather": 1359,
#         "minutes_delayed_total": 78878
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 25665,
#         "num_of_delays_carrier": "794",
#         "num_of_delays_late_aircraft": 1222.0,
#         "num_of_delays_nas": 3132,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 114,
#         "num_of_delays_total": 5269,
#         "minutes_delayed_carrier": 50136.0,
#         "minutes_delayed_late_aircraft": 72868,
#         "minutes_delayed_nas": 164398.0,
#         "minutes_delayed_security": 208,
#         "minutes_delayed_weather": 7256,
#         "minutes_delayed_total": 294866
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 6543,
#         "num_of_delays_carrier": "447",
#         "num_of_delays_late_aircraft": 491.0,
#         "num_of_delays_nas": 671,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 23,
#         "num_of_delays_total": 1635,
#         "minutes_delayed_carrier": 21755.0,
#         "minutes_delayed_late_aircraft": 28887,
#         "minutes_delayed_nas": 20705.0,
#         "minutes_delayed_security": 44,
#         "minutes_delayed_weather": 1285,
#         "minutes_delayed_total": 72676
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 9327,
#         "num_of_delays_carrier": "599",
#         "num_of_delays_late_aircraft": 457.0,
#         "num_of_delays_nas": 1010,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 57,
#         "num_of_delays_total": 2122,
#         "minutes_delayed_carrier": 30760.0,
#         "minutes_delayed_late_aircraft": 27302,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 6,
#         "minutes_delayed_weather": 3178,
#         "minutes_delayed_total": 110995
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "",
#         "month": "Febuary",
#         "year": 2005.0,
#         "num_of_flights_total": 12404,
#         "num_of_delays_carrier": "645",
#         "num_of_delays_late_aircraft": 463.0,
#         "num_of_delays_nas": 752,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 79,
#         "num_of_delays_total": 1947,
#         "minutes_delayed_carrier": 32336.0,
#         "minutes_delayed_late_aircraft": 23087,
#         "minutes_delayed_nas": 24544.0,
#         "minutes_delayed_security": 293,
#         "minutes_delayed_weather": 4614,
#         "minutes_delayed_total": 84874
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 37806,
#         "num_of_delays_carrier": "1462",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 5697,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 423,
#         "num_of_delays_total": 9431,
#         "minutes_delayed_carrier": 51902.253440367,
#         "minutes_delayed_late_aircraft": 150766,
#         "minutes_delayed_nas": 396191.0,
#         "minutes_delayed_security": 568,
#         "minutes_delayed_weather": 33379,
#         "minutes_delayed_total": 691887
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 12979,
#         "num_of_delays_carrier": "852",
#         "num_of_delays_late_aircraft": 586.0,
#         "num_of_delays_nas": 530,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 85,
#         "num_of_delays_total": 2062,
#         "minutes_delayed_carrier": 40782.0,
#         "minutes_delayed_late_aircraft": 35283,
#         "minutes_delayed_nas": 15775.0,
#         "minutes_delayed_security": 351,
#         "minutes_delayed_weather": 5265,
#         "minutes_delayed_total": 97456
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 11249,
#         "num_of_delays_carrier": "372",
#         "num_of_delays_late_aircraft": 724.0,
#         "num_of_delays_nas": 777,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 43,
#         "num_of_delays_total": 1921,
#         "minutes_delayed_carrier": 20587.0,
#         "minutes_delayed_late_aircraft": 53667,
#         "minutes_delayed_nas": 27186.0,
#         "minutes_delayed_security": 459,
#         "minutes_delayed_weather": 3505,
#         "minutes_delayed_total": 105404
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 28785,
#         "num_of_delays_carrier": "1026",
#         "num_of_delays_late_aircraft": 1665.0,
#         "num_of_delays_nas": 3686,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 159,
#         "num_of_delays_total": 6544,
#         "minutes_delayed_carrier": 65241.0,
#         "minutes_delayed_late_aircraft": 103993,
#         "minutes_delayed_nas": 178333.0,
#         "minutes_delayed_security": 457,
#         "minutes_delayed_weather": 11672,
#         "minutes_delayed_total": 359696
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 7298,
#         "num_of_delays_carrier": "464",
#         "num_of_delays_late_aircraft": 489.0,
#         "num_of_delays_nas": 343,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 27,
#         "num_of_delays_total": 1324,
#         "minutes_delayed_carrier": 19643.0,
#         "minutes_delayed_late_aircraft": 24033,
#         "minutes_delayed_nas": 9515.0,
#         "minutes_delayed_security": 112,
#         "minutes_delayed_weather": 1323,
#         "minutes_delayed_total": 54626
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 10532,
#         "num_of_delays_carrier": "714",
#         "num_of_delays_late_aircraft": 455.0,
#         "num_of_delays_nas": 923,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 54,
#         "num_of_delays_total": 2148,
#         "minutes_delayed_carrier": 35374.0,
#         "minutes_delayed_late_aircraft": 27922,
#         "minutes_delayed_nas": 51401.0,
#         "minutes_delayed_security": 118,
#         "minutes_delayed_weather": 3802,
#         "minutes_delayed_total": 118617
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "March",
#         "year": 2005.0,
#         "num_of_flights_total": 14115,
#         "num_of_delays_carrier": "878",
#         "num_of_delays_late_aircraft": 614.0,
#         "num_of_delays_nas": 820,
#         "num_of_delays_security": 15,
#         "num_of_delays_weather": 102,
#         "num_of_delays_total": 2426,
#         "minutes_delayed_carrier": 38323.0,
#         "minutes_delayed_late_aircraft": 27635,
#         "minutes_delayed_nas": 31907.0,
#         "minutes_delayed_security": 606,
#         "minutes_delayed_weather": 4760,
#         "minutes_delayed_total": 103231
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "April",
#         "year": null,
#         "num_of_flights_total": 36881,
#         "num_of_delays_carrier": "1283",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 2734,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 316,
#         "num_of_delays_total": 5748,
#         "minutes_delayed_carrier": 87994.0,
#         "minutes_delayed_late_aircraft": 104417,
#         "minutes_delayed_nas": 173772.0,
#         "minutes_delayed_security": 295,
#         "minutes_delayed_weather": 30566,
#         "minutes_delayed_total": 397044
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 12275,
#         "num_of_delays_carrier": "627",
#         "num_of_delays_late_aircraft": 350.0,
#         "num_of_delays_nas": 440,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 57,
#         "num_of_delays_total": 1476,
#         "minutes_delayed_carrier": 31124.0,
#         "minutes_delayed_late_aircraft": 19422,
#         "minutes_delayed_nas": 13945.0,
#         "minutes_delayed_security": 44,
#         "minutes_delayed_weather": 4215,
#         "minutes_delayed_total": 68750
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 10997,
#         "num_of_delays_carrier": "275",
#         "num_of_delays_late_aircraft": 517.0,
#         "num_of_delays_nas": 677,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 32,
#         "num_of_delays_total": 1508,
#         "minutes_delayed_carrier": 14163.0,
#         "minutes_delayed_late_aircraft": 32723,
#         "minutes_delayed_nas": 30587.0,
#         "minutes_delayed_security": 245,
#         "minutes_delayed_weather": 2344,
#         "minutes_delayed_total": 80062
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 27634,
#         "num_of_delays_carrier": "811",
#         "num_of_delays_late_aircraft": 980.0,
#         "num_of_delays_nas": 1900,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 93,
#         "num_of_delays_total": 3786,
#         "minutes_delayed_carrier": 50443.0,
#         "minutes_delayed_late_aircraft": 53496,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 186,
#         "minutes_delayed_weather": 5791,
#         "minutes_delayed_total": 188222
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 7091,
#         "num_of_delays_carrier": "364",
#         "num_of_delays_late_aircraft": 369.0,
#         "num_of_delays_nas": 343,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 15,
#         "num_of_delays_total": 1095,
#         "minutes_delayed_carrier": 15602.0,
#         "minutes_delayed_late_aircraft": 15994,
#         "minutes_delayed_nas": 10015.0,
#         "minutes_delayed_security": 59,
#         "minutes_delayed_weather": 792,
#         "minutes_delayed_total": 42462
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 10210,
#         "num_of_delays_carrier": "532",
#         "num_of_delays_late_aircraft": 339.0,
#         "num_of_delays_nas": 563,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 29,
#         "num_of_delays_total": 1470,
#         "minutes_delayed_carrier": 26083.0,
#         "minutes_delayed_late_aircraft": 19990,
#         "minutes_delayed_nas": 25118.0,
#         "minutes_delayed_security": 342,
#         "minutes_delayed_weather": 1564,
#         "minutes_delayed_total": 73097
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "April",
#         "year": 2005.0,
#         "num_of_flights_total": 13398,
#         "num_of_delays_carrier": "590",
#         "num_of_delays_late_aircraft": 382.0,
#         "num_of_delays_nas": 528,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 42,
#         "num_of_delays_total": 1546,
#         "minutes_delayed_carrier": 26829.0,
#         "minutes_delayed_late_aircraft": 17311,
#         "minutes_delayed_nas": 16667.0,
#         "minutes_delayed_security": 220,
#         "minutes_delayed_weather": 2063,
#         "minutes_delayed_total": 63090
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 38076,
#         "num_of_delays_carrier": "1201",
#         "num_of_delays_late_aircraft": 1195.0,
#         "num_of_delays_nas": 3134,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 278,
#         "num_of_delays_total": 5813,
#         "minutes_delayed_carrier": 82828.0,
#         "minutes_delayed_late_aircraft": 79428,
#         "minutes_delayed_nas": 155827.0,
#         "minutes_delayed_security": 74,
#         "minutes_delayed_weather": 20017,
#         "minutes_delayed_total": 338174
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 16211,
#         "num_of_delays_carrier": "764",
#         "num_of_delays_late_aircraft": 668.0,
#         "num_of_delays_nas": 694,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 50,
#         "num_of_delays_total": 2174,
#         "minutes_delayed_carrier": 37884.0,
#         "minutes_delayed_late_aircraft": 38015,
#         "minutes_delayed_nas": 22509.0,
#         "minutes_delayed_security": 0,
#         "minutes_delayed_weather": 3730,
#         "minutes_delayed_total": 102138
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 11189,
#         "num_of_delays_carrier": "285",
#         "num_of_delays_late_aircraft": 649.0,
#         "num_of_delays_nas": 1049,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 36,
#         "num_of_delays_total": 2020,
#         "minutes_delayed_carrier": 15838.0,
#         "minutes_delayed_late_aircraft": 40615,
#         "minutes_delayed_nas": 34597.0,
#         "minutes_delayed_security": 70,
#         "minutes_delayed_weather": 2591,
#         "minutes_delayed_total": 93711
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 28523,
#         "num_of_delays_carrier": "861",
#         "num_of_delays_late_aircraft": 1375.0,
#         "num_of_delays_nas": 2833,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 123,
#         "num_of_delays_total": 5195,
#         "minutes_delayed_carrier": 57526.0,
#         "minutes_delayed_late_aircraft": 98770,
#         "minutes_delayed_nas": 169823.0,
#         "minutes_delayed_security": 123,
#         "minutes_delayed_weather": 9667,
#         "minutes_delayed_total": 335909
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 7512,
#         "num_of_delays_carrier": "411",
#         "num_of_delays_late_aircraft": 383.0,
#         "num_of_delays_nas": 284,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 38,
#         "num_of_delays_total": 1117,
#         "minutes_delayed_carrier": 17815.0,
#         "minutes_delayed_late_aircraft": 17289,
#         "minutes_delayed_nas": 9276.0,
#         "minutes_delayed_security": 77,
#         "minutes_delayed_weather": 3126,
#         "minutes_delayed_total": 47583
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 10954,
#         "num_of_delays_carrier": "577",
#         "num_of_delays_late_aircraft": 438.0,
#         "num_of_delays_nas": 1158,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 45,
#         "num_of_delays_total": 2217,
#         "minutes_delayed_carrier": 28810.0,
#         "minutes_delayed_late_aircraft": 27188,
#         "minutes_delayed_nas": 63563.0,
#         "minutes_delayed_security": 81,
#         "minutes_delayed_weather": 3237,
#         "minutes_delayed_total": 122879
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "May",
#         "year": 2005.0,
#         "num_of_flights_total": 13822,
#         "num_of_delays_carrier": "601",
#         "num_of_delays_late_aircraft": 371.0,
#         "num_of_delays_nas": 454,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 53,
#         "num_of_delays_total": 1480,
#         "minutes_delayed_carrier": 29853.0,
#         "minutes_delayed_late_aircraft": 17377,
#         "minutes_delayed_nas": 14517.0,
#         "minutes_delayed_security": 76,
#         "minutes_delayed_weather": 3133,
#         "minutes_delayed_total": 64956
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 37209,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 6892,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 479,
#         "num_of_delays_total": 10986,
#         "minutes_delayed_carrier": 119455.0,
#         "minutes_delayed_late_aircraft": 134768,
#         "minutes_delayed_nas": 343189.0,
#         "minutes_delayed_security": 390,
#         "minutes_delayed_weather": 32914,
#         "minutes_delayed_total": 630716
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 16953,
#         "num_of_delays_carrier": "1058",
#         "num_of_delays_late_aircraft": 1118.0,
#         "num_of_delays_nas": 993,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 137,
#         "num_of_delays_total": 3310,
#         "minutes_delayed_carrier": 57649.0,
#         "minutes_delayed_late_aircraft": 74824,
#         "minutes_delayed_nas": 40437.0,
#         "minutes_delayed_security": 122,
#         "minutes_delayed_weather": 10065,
#         "minutes_delayed_total": 183097
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 10743,
#         "num_of_delays_carrier": "425",
#         "num_of_delays_late_aircraft": 1040.0,
#         "num_of_delays_nas": 1392,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 64,
#         "num_of_delays_total": 2926,
#         "minutes_delayed_carrier": 26398.0,
#         "minutes_delayed_late_aircraft": 88487,
#         "minutes_delayed_nas": 75609.0,
#         "minutes_delayed_security": 65,
#         "minutes_delayed_weather": 5726,
#         "minutes_delayed_total": 196285
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 27756,
#         "num_of_delays_carrier": "1374",
#         "num_of_delays_late_aircraft": 2329.0,
#         "num_of_delays_nas": 3726,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 210,
#         "num_of_delays_total": 7643,
#         "minutes_delayed_carrier": 92424.0,
#         "minutes_delayed_late_aircraft": 165364,
#         "minutes_delayed_nas": 205599.0,
#         "minutes_delayed_security": 139,
#         "minutes_delayed_weather": 16946,
#         "minutes_delayed_total": 480472
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 7574,
#         "num_of_delays_carrier": "573",
#         "num_of_delays_late_aircraft": 604.0,
#         "num_of_delays_nas": 440,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 43,
#         "num_of_delays_total": 1661,
#         "minutes_delayed_carrier": 26938.0,
#         "minutes_delayed_late_aircraft": 32680,
#         "minutes_delayed_nas": 15883.0,
#         "minutes_delayed_security": 200,
#         "minutes_delayed_weather": 2974,
#         "minutes_delayed_total": 78675
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 11089,
#         "num_of_delays_carrier": "876",
#         "num_of_delays_late_aircraft": 737.0,
#         "num_of_delays_nas": 1288,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 71,
#         "num_of_delays_total": 2978,
#         "minutes_delayed_carrier": 48831.0,
#         "minutes_delayed_late_aircraft": 47574,
#         "minutes_delayed_nas": 56454.0,
#         "minutes_delayed_security": 208,
#         "minutes_delayed_weather": 5393,
#         "minutes_delayed_total": 158460
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "",
#         "month": "June",
#         "year": 2005.0,
#         "num_of_flights_total": 13860,
#         "num_of_delays_carrier": "788",
#         "num_of_delays_late_aircraft": 642.0,
#         "num_of_delays_nas": 670,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 95,
#         "num_of_delays_total": 2203,
#         "minutes_delayed_carrier": 37008.0,
#         "minutes_delayed_late_aircraft": 31149,
#         "minutes_delayed_nas": null,
#         "minutes_delayed_security": 162,
#         "minutes_delayed_weather": 5223,
#         "minutes_delayed_total": 98063
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "July",
#         "year": null,
#         "num_of_flights_total": 37584,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 8704,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 466,
#         "num_of_delays_total": 13699,
#         "minutes_delayed_carrier": 156293.0,
#         "minutes_delayed_late_aircraft": 219063,
#         "minutes_delayed_nas": 574857.0,
#         "minutes_delayed_security": 678,
#         "minutes_delayed_weather": 38476,
#         "minutes_delayed_total": 989367
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 17989,
#         "num_of_delays_carrier": "1195",
#         "num_of_delays_late_aircraft": 1141.0,
#         "num_of_delays_nas": 863,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 121,
#         "num_of_delays_total": 3323,
#         "minutes_delayed_carrier": 67702.0,
#         "minutes_delayed_late_aircraft": 78077,
#         "minutes_delayed_nas": 32694.0,
#         "minutes_delayed_security": 124,
#         "minutes_delayed_weather": 8515,
#         "minutes_delayed_total": 187112
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 11152,
#         "num_of_delays_carrier": "442",
#         "num_of_delays_late_aircraft": 1170.0,
#         "num_of_delays_nas": 1548,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 79,
#         "num_of_delays_total": 3245,
#         "minutes_delayed_carrier": 27971.0,
#         "minutes_delayed_late_aircraft": 97189,
#         "minutes_delayed_nas": 86274.0,
#         "minutes_delayed_security": 217,
#         "minutes_delayed_weather": 6752,
#         "minutes_delayed_total": 218403
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 28283,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 2241.0,
#         "num_of_delays_nas": 3547,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 213,
#         "num_of_delays_total": 7641,
#         "minutes_delayed_carrier": 121159.0,
#         "minutes_delayed_late_aircraft": 181764,
#         "minutes_delayed_nas": 237346.0,
#         "minutes_delayed_security": 443,
#         "minutes_delayed_weather": 17190,
#         "minutes_delayed_total": 557902
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 7862,
#         "num_of_delays_carrier": "664",
#         "num_of_delays_late_aircraft": 675.0,
#         "num_of_delays_nas": 359,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 70,
#         "num_of_delays_total": 1769,
#         "minutes_delayed_carrier": 33005.0,
#         "minutes_delayed_late_aircraft": 39105,
#         "minutes_delayed_nas": 14402.0,
#         "minutes_delayed_security": 57,
#         "minutes_delayed_weather": 4912,
#         "minutes_delayed_total": 91481
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 11579,
#         "num_of_delays_carrier": "896",
#         "num_of_delays_late_aircraft": 723.0,
#         "num_of_delays_nas": 826,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 93,
#         "num_of_delays_total": 2548,
#         "minutes_delayed_carrier": 49421.0,
#         "minutes_delayed_late_aircraft": 50665,
#         "minutes_delayed_nas": 39209.0,
#         "minutes_delayed_security": 128,
#         "minutes_delayed_weather": 6918,
#         "minutes_delayed_total": 146341
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "July",
#         "year": 2005.0,
#         "num_of_flights_total": 14472,
#         "num_of_delays_carrier": "809",
#         "num_of_delays_late_aircraft": 733.0,
#         "num_of_delays_nas": 606,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 101,
#         "num_of_delays_total": 2257,
#         "minutes_delayed_carrier": 39224.0,
#         "minutes_delayed_late_aircraft": 38201,
#         "minutes_delayed_nas": 22061.0,
#         "minutes_delayed_security": 171,
#         "minutes_delayed_weather": 6457,
#         "minutes_delayed_total": 106114
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 37886,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 1109.1040723982,
#         "num_of_delays_nas": 8440,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 381,
#         "num_of_delays_total": 12861,
#         "minutes_delayed_carrier": 140274.0,
#         "minutes_delayed_late_aircraft": 154147,
#         "minutes_delayed_nas": 487160.0,
#         "minutes_delayed_security": 459,
#         "minutes_delayed_weather": 28593,
#         "minutes_delayed_total": 810633
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 17827,
#         "num_of_delays_carrier": "1013",
#         "num_of_delays_late_aircraft": 788.0,
#         "num_of_delays_nas": 753,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 120,
#         "num_of_delays_total": 2682,
#         "minutes_delayed_carrier": 50588.0,
#         "minutes_delayed_late_aircraft": 44658,
#         "minutes_delayed_nas": 27912.0,
#         "minutes_delayed_security": 411,
#         "minutes_delayed_weather": 8388,
#         "minutes_delayed_total": 131957
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 11064,
#         "num_of_delays_carrier": "393",
#         "num_of_delays_late_aircraft": 763.0,
#         "num_of_delays_nas": 922,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 54,
#         "num_of_delays_total": 2133,
#         "minutes_delayed_carrier": 21463.0,
#         "minutes_delayed_late_aircraft": 52261,
#         "minutes_delayed_nas": 33574.0,
#         "minutes_delayed_security": 184,
#         "minutes_delayed_weather": 3582,
#         "minutes_delayed_total": 111064
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 28662,
#         "num_of_delays_carrier": "1273",
#         "num_of_delays_late_aircraft": 1663.0,
#         "num_of_delays_nas": 2422,
#         "num_of_delays_security": 12,
#         "num_of_delays_weather": 163,
#         "num_of_delays_total": 5533,
#         "minutes_delayed_carrier": 76496.0,
#         "minutes_delayed_late_aircraft": 100348,
#         "minutes_delayed_nas": 120036.0,
#         "minutes_delayed_security": 533,
#         "minutes_delayed_weather": 11190,
#         "minutes_delayed_total": 308603
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 7946,
#         "num_of_delays_carrier": "611",
#         "num_of_delays_late_aircraft": 571.0,
#         "num_of_delays_nas": 388,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 49,
#         "num_of_delays_total": 1629,
#         "minutes_delayed_carrier": 27822.0,
#         "minutes_delayed_late_aircraft": 27741,
#         "minutes_delayed_nas": 13411.0,
#         "minutes_delayed_security": 346,
#         "minutes_delayed_weather": 3384,
#         "minutes_delayed_total": 72704
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 11598,
#         "num_of_delays_carrier": "797",
#         "num_of_delays_late_aircraft": 683.0,
#         "num_of_delays_nas": 1078,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 69,
#         "num_of_delays_total": 2638,
#         "minutes_delayed_carrier": 41615.0,
#         "minutes_delayed_late_aircraft": 41956,
#         "minutes_delayed_nas": 51040.0,
#         "minutes_delayed_security": 355,
#         "minutes_delayed_weather": 4717,
#         "minutes_delayed_total": 139683
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "August",
#         "year": 2005.0,
#         "num_of_flights_total": 14630,
#         "num_of_delays_carrier": "822",
#         "num_of_delays_late_aircraft": 684.0,
#         "num_of_delays_nas": 602,
#         "num_of_delays_security": 17,
#         "num_of_delays_weather": 82,
#         "num_of_delays_total": 2206,
#         "minutes_delayed_carrier": 39182.0,
#         "minutes_delayed_late_aircraft": 33107,
#         "minutes_delayed_nas": 19181.0,
#         "minutes_delayed_security": 438,
#         "minutes_delayed_weather": 5536,
#         "minutes_delayed_total": 97444
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 33631,
#         "num_of_delays_carrier": "1247",
#         "num_of_delays_late_aircraft": 977.0,
#         "num_of_delays_nas": 2374,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 127,
#         "num_of_delays_total": 4731,
#         "minutes_delayed_carrier": 84909.0,
#         "minutes_delayed_late_aircraft": 48728,
#         "minutes_delayed_nas": 76158.0,
#         "minutes_delayed_security": 199,
#         "minutes_delayed_weather": 6153,
#         "minutes_delayed_total": 216147
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 16297,
#         "num_of_delays_carrier": "611",
#         "num_of_delays_late_aircraft": 461.0,
#         "num_of_delays_nas": 515,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 42,
#         "num_of_delays_total": 1632,
#         "minutes_delayed_carrier": 33657.0,
#         "minutes_delayed_late_aircraft": 24519,
#         "minutes_delayed_nas": 15970.0,
#         "minutes_delayed_security": 175,
#         "minutes_delayed_weather": 2736,
#         "minutes_delayed_total": 77057
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 9398,
#         "num_of_delays_carrier": "231",
#         "num_of_delays_late_aircraft": 357.0,
#         "num_of_delays_nas": 527,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 19,
#         "num_of_delays_total": 1134,
#         "minutes_delayed_carrier": 12036.0,
#         "minutes_delayed_late_aircraft": 21710,
#         "minutes_delayed_nas": 15985.0,
#         "minutes_delayed_security": 11,
#         "minutes_delayed_weather": 1552,
#         "minutes_delayed_total": 51294
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 27474,
#         "num_of_delays_carrier": "830",
#         "num_of_delays_late_aircraft": 1262.0,
#         "num_of_delays_nas": 2500,
#         "num_of_delays_security": 6,
#         "num_of_delays_weather": 119,
#         "num_of_delays_total": 4717,
#         "minutes_delayed_carrier": 53005.0,
#         "minutes_delayed_late_aircraft": 77123,
#         "minutes_delayed_nas": 129495.0,
#         "minutes_delayed_security": 144,
#         "minutes_delayed_weather": 9102,
#         "minutes_delayed_total": 268869
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 7451,
#         "num_of_delays_carrier": "414",
#         "num_of_delays_late_aircraft": 419.0,
#         "num_of_delays_nas": 420,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 31,
#         "num_of_delays_total": 1286,
#         "minutes_delayed_carrier": 51902.253440367,
#         "minutes_delayed_late_aircraft": 17110,
#         "minutes_delayed_nas": 12249.0,
#         "minutes_delayed_security": 119,
#         "minutes_delayed_weather": 1607,
#         "minutes_delayed_total": 47963
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 10765,
#         "num_of_delays_carrier": "660",
#         "num_of_delays_late_aircraft": 417.0,
#         "num_of_delays_nas": 1084,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 42,
#         "num_of_delays_total": 2212,
#         "minutes_delayed_carrier": 31232.0,
#         "minutes_delayed_late_aircraft": 23699,
#         "minutes_delayed_nas": 45912.0,
#         "minutes_delayed_security": 261,
#         "minutes_delayed_weather": 2031,
#         "minutes_delayed_total": 103135
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "September",
#         "year": 2005.0,
#         "num_of_flights_total": 13720,
#         "num_of_delays_carrier": "613",
#         "num_of_delays_late_aircraft": 432.0,
#         "num_of_delays_nas": 550,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 41,
#         "num_of_delays_total": 1641,
#         "minutes_delayed_carrier": 29844.0,
#         "minutes_delayed_late_aircraft": 16681,
#         "minutes_delayed_nas": 16287.0,
#         "minutes_delayed_security": 141,
#         "minutes_delayed_weather": 2775,
#         "minutes_delayed_total": 65728
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 35282,
#         "num_of_delays_carrier": "1288",
#         "num_of_delays_late_aircraft": 1402.0,
#         "num_of_delays_nas": 4520,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 276,
#         "num_of_delays_total": 7493,
#         "minutes_delayed_carrier": 84911.0,
#         "minutes_delayed_late_aircraft": 82014,
#         "minutes_delayed_nas": 204257.0,
#         "minutes_delayed_security": 452,
#         "minutes_delayed_weather": 17084,
#         "minutes_delayed_total": 388718
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 16498,
#         "num_of_delays_carrier": "706",
#         "num_of_delays_late_aircraft": 590.0,
#         "num_of_delays_nas": 526,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 51,
#         "num_of_delays_total": 1876,
#         "minutes_delayed_carrier": 36179.0,
#         "minutes_delayed_late_aircraft": 41825,
#         "minutes_delayed_nas": 17897.0,
#         "minutes_delayed_security": 86,
#         "minutes_delayed_weather": 4676,
#         "minutes_delayed_total": 100663
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 9262,
#         "num_of_delays_carrier": "317",
#         "num_of_delays_late_aircraft": 479.0,
#         "num_of_delays_nas": 635,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 16,
#         "num_of_delays_total": 1447,
#         "minutes_delayed_carrier": 17936.0,
#         "minutes_delayed_late_aircraft": 29914,
#         "minutes_delayed_nas": 19606.0,
#         "minutes_delayed_security": 65,
#         "minutes_delayed_weather": 1182,
#         "minutes_delayed_total": 68703
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 29083,
#         "num_of_delays_carrier": "985",
#         "num_of_delays_late_aircraft": 1101.0,
#         "num_of_delays_nas": 1368,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 79,
#         "num_of_delays_total": 3538,
#         "minutes_delayed_carrier": 55588.0,
#         "minutes_delayed_late_aircraft": 65317,
#         "minutes_delayed_nas": 61542.0,
#         "minutes_delayed_security": 221,
#         "minutes_delayed_weather": 6400,
#         "minutes_delayed_total": 189068
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 7641,
#         "num_of_delays_carrier": "478",
#         "num_of_delays_late_aircraft": 495.0,
#         "num_of_delays_nas": 308,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 37,
#         "num_of_delays_total": 1321,
#         "minutes_delayed_carrier": 19788.0,
#         "minutes_delayed_late_aircraft": 21984,
#         "minutes_delayed_nas": 9451.0,
#         "minutes_delayed_security": 124,
#         "minutes_delayed_weather": 2341,
#         "minutes_delayed_total": 53688
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 11104,
#         "num_of_delays_carrier": "676",
#         "num_of_delays_late_aircraft": 516.0,
#         "num_of_delays_nas": 904,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 37,
#         "num_of_delays_total": 2134,
#         "minutes_delayed_carrier": 30973.0,
#         "minutes_delayed_late_aircraft": 32199,
#         "minutes_delayed_nas": 44132.0,
#         "minutes_delayed_security": 79,
#         "minutes_delayed_weather": 2453,
#         "minutes_delayed_total": 109836
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "October",
#         "year": 2005.0,
#         "num_of_flights_total": 13962,
#         "num_of_delays_carrier": "570",
#         "num_of_delays_late_aircraft": 449.0,
#         "num_of_delays_nas": 372,
#         "num_of_delays_security": 9,
# ...
#         "minutes_delayed_weather": 1282,
#         "minutes_delayed_total": 35527
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "September",
#         "year": 2015.0,
#         "num_of_flights_total": 13318,
#         "num_of_delays_carrier": "479",
#         "num_of_delays_late_aircraft": 637.0,
#         "num_of_delays_nas": 741,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 55,
#         "num_of_delays_total": 1913,
#         "minutes_delayed_carrier": 29865.0,
#         "minutes_delayed_late_aircraft": 36997,
#         "minutes_delayed_nas": 35048.0,
#         "minutes_delayed_security": 82,
#         "minutes_delayed_weather": 2544,
#         "minutes_delayed_total": 104536
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "September",
#         "year": 2015.0,
#         "num_of_flights_total": 8406,
#         "num_of_delays_carrier": "231",
#         "num_of_delays_late_aircraft": 292.0,
#         "num_of_delays_nas": 131,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 19,
#         "num_of_delays_total": 671,
#         "minutes_delayed_carrier": 18863.0,
#         "minutes_delayed_late_aircraft": 16185,
#         "minutes_delayed_nas": 3756.0,
#         "minutes_delayed_security": 17,
#         "minutes_delayed_weather": 1285,
#         "minutes_delayed_total": 40106
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 32594,
#         "num_of_delays_carrier": "1021",
#         "num_of_delays_late_aircraft": 1034.0,
#         "num_of_delays_nas": 1010,
#         "num_of_delays_security": 4,
#         "num_of_delays_weather": 30,
#         "num_of_delays_total": 3098,
#         "minutes_delayed_carrier": 87953.0,
#         "minutes_delayed_late_aircraft": 60372,
#         "minutes_delayed_nas": 33160.0,
#         "minutes_delayed_security": 216,
#         "minutes_delayed_weather": 4122,
#         "minutes_delayed_total": 185823
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 18125,
#         "num_of_delays_carrier": "669",
#         "num_of_delays_late_aircraft": 743.0,
#         "num_of_delays_nas": 744,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 41,
#         "num_of_delays_total": 2200,
#         "minutes_delayed_carrier": 47720.0,
#         "minutes_delayed_late_aircraft": 44085,
#         "minutes_delayed_nas": 26533.0,
#         "minutes_delayed_security": 48,
#         "minutes_delayed_weather": 3359,
#         "minutes_delayed_total": 121745
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 3000,
#         "num_of_delays_carrier": "140",
#         "num_of_delays_late_aircraft": 102.0,
#         "num_of_delays_nas": 100,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 11,
#         "num_of_delays_total": 352,
#         "minutes_delayed_carrier": 7885.0,
#         "minutes_delayed_late_aircraft": 6417,
#         "minutes_delayed_nas": 3877.0,
#         "minutes_delayed_security": 0,
#         "minutes_delayed_weather": 693,
#         "minutes_delayed_total": 18872
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 27608,
#         "num_of_delays_carrier": "847",
#         "num_of_delays_late_aircraft": 1077.0,
#         "num_of_delays_nas": 1257,
#         "num_of_delays_security": 8,
#         "num_of_delays_weather": 45,
#         "num_of_delays_total": 3236,
#         "minutes_delayed_carrier": 71131.0,
#         "minutes_delayed_late_aircraft": 70611,
#         "minutes_delayed_nas": 42078.0,
#         "minutes_delayed_security": 238,
#         "minutes_delayed_weather": 3917,
#         "minutes_delayed_total": 187975
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 6207,
#         "num_of_delays_carrier": "245",
#         "num_of_delays_late_aircraft": 263.0,
#         "num_of_delays_nas": 141,
#         "num_of_delays_security": 2,
#         "num_of_delays_weather": 12,
#         "num_of_delays_total": 661,
#         "minutes_delayed_carrier": 12002.0,
#         "minutes_delayed_late_aircraft": 15836,
#         "minutes_delayed_nas": 5121.0,
#         "minutes_delayed_security": 61,
#         "minutes_delayed_weather": 955,
#         "minutes_delayed_total": 33975
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 14170,
#         "num_of_delays_carrier": "510",
#         "num_of_delays_late_aircraft": 753.0,
#         "num_of_delays_nas": 792,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 39,
#         "num_of_delays_total": 2096,
#         "minutes_delayed_carrier": 33326.0,
#         "minutes_delayed_late_aircraft": 50740,
#         "minutes_delayed_nas": 41157.0,
#         "minutes_delayed_security": 2,
#         "minutes_delayed_weather": 2948,
#         "minutes_delayed_total": 128173
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "October",
#         "year": 2015.0,
#         "num_of_flights_total": 8764,
#         "num_of_delays_carrier": "234",
#         "num_of_delays_late_aircraft": 257.0,
#         "num_of_delays_nas": 150,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 10,
#         "num_of_delays_total": 652,
#         "minutes_delayed_carrier": 15522.0,
#         "minutes_delayed_late_aircraft": 14155,
#         "minutes_delayed_nas": -999.0,
#         "minutes_delayed_security": 40,
#         "minutes_delayed_weather": 1765,
#         "minutes_delayed_total": 35799
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 30903,
#         "num_of_delays_carrier": "1112",
#         "num_of_delays_late_aircraft": 1420.0,
#         "num_of_delays_nas": 1457,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 61,
#         "num_of_delays_total": 4060,
#         "minutes_delayed_carrier": 95024.0,
#         "minutes_delayed_late_aircraft": 84231,
#         "minutes_delayed_nas": 46457.0,
#         "minutes_delayed_security": 576,
#         "minutes_delayed_weather": 5921,
#         "minutes_delayed_total": 232209
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 17120,
#         "num_of_delays_carrier": "751",
#         "num_of_delays_late_aircraft": 1031.0,
#         "num_of_delays_nas": 1197,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 93,
#         "num_of_delays_total": 3076,
#         "minutes_delayed_carrier": 54704.0,
#         "minutes_delayed_late_aircraft": 69918,
#         "minutes_delayed_nas": 50919.0,
#         "minutes_delayed_security": 63,
#         "minutes_delayed_weather": 9509,
#         "minutes_delayed_total": 185113
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 2684,
#         "num_of_delays_carrier": "134",
#         "num_of_delays_late_aircraft": 106.0,
#         "num_of_delays_nas": 65,
#         "num_of_delays_security": 1,
#         "num_of_delays_weather": 15,
#         "num_of_delays_total": 320,
#         "minutes_delayed_carrier": 8017.0,
#         "minutes_delayed_late_aircraft": 9193,
#         "minutes_delayed_nas": 2183.0,
#         "minutes_delayed_security": 36,
#         "minutes_delayed_weather": 901,
#         "minutes_delayed_total": 20330
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 26063,
#         "num_of_delays_carrier": "838",
#         "num_of_delays_late_aircraft": 1287.0,
#         "num_of_delays_nas": 1724,
#         "num_of_delays_security": 7,
#         "num_of_delays_weather": 110,
#         "num_of_delays_total": 3962,
#         "minutes_delayed_carrier": 72305.0,
#         "minutes_delayed_late_aircraft": 101335,
#         "minutes_delayed_nas": 150030.0,
#         "minutes_delayed_security": 317,
#         "minutes_delayed_weather": 14731,
#         "minutes_delayed_total": 338718
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 5965,
#         "num_of_delays_carrier": "307",
#         "num_of_delays_late_aircraft": 364.0,
#         "num_of_delays_nas": 284,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 36,
#         "num_of_delays_total": 997,
#         "minutes_delayed_carrier": 15502.0,
#         "minutes_delayed_late_aircraft": 18896,
#         "minutes_delayed_nas": -999.0,
#         "minutes_delayed_security": 253,
#         "minutes_delayed_weather": 3615,
#         "minutes_delayed_total": 50942
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 13527,
#         "num_of_delays_carrier": "585",
#         "num_of_delays_late_aircraft": 766.0,
#         "num_of_delays_nas": 772,
#         "num_of_delays_security": 3,
#         "num_of_delays_weather": 65,
#         "num_of_delays_total": 2189,
#         "minutes_delayed_carrier": 39934.0,
#         "minutes_delayed_late_aircraft": 51704,
#         "minutes_delayed_nas": 31587.0,
#         "minutes_delayed_security": 165,
#         "minutes_delayed_weather": 4625,
#         "minutes_delayed_total": 128015
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "November",
#         "year": 2015.0,
#         "num_of_flights_total": 8435,
#         "num_of_delays_carrier": "288",
#         "num_of_delays_late_aircraft": 379.0,
#         "num_of_delays_nas": 294,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 21,
#         "num_of_delays_total": 981,
#         "minutes_delayed_carrier": 21745.0,
#         "minutes_delayed_late_aircraft": 20938,
#         "minutes_delayed_nas": 8777.0,
#         "minutes_delayed_security": 41,
#         "minutes_delayed_weather": 2295,
#         "minutes_delayed_total": 53796
#     },
#     {
#         "airport_code": "ATL",
#         "airport_name": "Atlanta, GA: Hartsfield-Jackson Atlanta International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 31030,
#         "num_of_delays_carrier": "1500+",
#         "num_of_delays_late_aircraft": 2176.0,
#         "num_of_delays_nas": 1616,
#         "num_of_delays_security": 10,
#         "num_of_delays_weather": 147,
#         "num_of_delays_total": 5474,
#         "minutes_delayed_carrier": 148033.0,
#         "minutes_delayed_late_aircraft": 173784,
#         "minutes_delayed_nas": 93850.0,
#         "minutes_delayed_security": 313,
#         "minutes_delayed_weather": 19532,
#         "minutes_delayed_total": 435512
#     },
#     {
#         "airport_code": "DEN",
#         "airport_name": "Denver, CO: Denver International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 18001,
#         "num_of_delays_carrier": "1001",
#         "num_of_delays_late_aircraft": 1463.0,
#         "num_of_delays_nas": 981,
#         "num_of_delays_security": 14,
#         "num_of_delays_weather": 152,
#         "num_of_delays_total": 3610,
#         "minutes_delayed_carrier": 64757.0,
#         "minutes_delayed_late_aircraft": 111638,
#         "minutes_delayed_nas": 60584.0,
#         "minutes_delayed_security": 405,
#         "minutes_delayed_weather": 20271,
#         "minutes_delayed_total": 257655
#     },
#     {
#         "airport_code": "IAD",
#         "airport_name": "Washington, DC: Washington Dulles International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 2799,
#         "num_of_delays_carrier": "182",
#         "num_of_delays_late_aircraft": 183.0,
#         "num_of_delays_nas": 61,
#         "num_of_delays_security": 0,
#         "num_of_delays_weather": 17,
#         "num_of_delays_total": 443,
#         "minutes_delayed_carrier": 51902.253440367,
#         "minutes_delayed_late_aircraft": 15438,
#         "minutes_delayed_nas": 2826.0,
#         "minutes_delayed_security": 0,
#         "minutes_delayed_weather": 1825,
#         "minutes_delayed_total": 31164
#     },
#     {
#         "airport_code": "ORD",
#         "airport_name": "Chicago, IL: Chicago O'Hare International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 25568,
#         "num_of_delays_carrier": "923",
#         "num_of_delays_late_aircraft": 1755.0,
#         "num_of_delays_nas": 1364,
#         "num_of_delays_security": 11,
#         "num_of_delays_weather": 180,
#         "num_of_delays_total": 4233,
#         "minutes_delayed_carrier": 80962.0,
#         "minutes_delayed_late_aircraft": 132055,
#         "minutes_delayed_nas": 72045.0,
#         "minutes_delayed_security": 435,
#         "minutes_delayed_weather": 22459,
#         "minutes_delayed_total": 307956
#     },
#     {
#         "airport_code": "SAN",
#         "airport_name": "San Diego, CA: San Diego International",
#         "month": "n/a",
#         "year": 2015.0,
#         "num_of_flights_total": 6231,
#         "num_of_delays_carrier": "480",
#         "num_of_delays_late_aircraft": 606.0,
#         "num_of_delays_nas": 256,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 37,
#         "num_of_delays_total": 1383,
#         "minutes_delayed_carrier": 25402.0,
#         "minutes_delayed_late_aircraft": 35796,
#         "minutes_delayed_nas": 9038.0,
#         "minutes_delayed_security": 161,
#         "minutes_delayed_weather": 2742,
#         "minutes_delayed_total": 73139
#     },
#     {
#         "airport_code": "SFO",
#         "airport_name": "San Francisco, CA: San Francisco International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 13833,
#         "num_of_delays_carrier": "757",
#         "num_of_delays_late_aircraft": 1180.0,
#         "num_of_delays_nas": 2372,
#         "num_of_delays_security": 9,
#         "num_of_delays_weather": 147,
#         "num_of_delays_total": 4465,
#         "minutes_delayed_carrier": 55283.0,
#         "minutes_delayed_late_aircraft": 96703,
#         "minutes_delayed_nas": 193525.0,
#         "minutes_delayed_security": 285,
#         "minutes_delayed_weather": 13788,
#         "minutes_delayed_total": 359584
#     },
#     {
#         "airport_code": "SLC",
#         "airport_name": "Salt Lake City, UT: Salt Lake City International",
#         "month": "December",
#         "year": 2015.0,
#         "num_of_flights_total": 8804,
#         "num_of_delays_carrier": "483",
#         "num_of_delays_late_aircraft": 796.0,
#         "num_of_delays_nas": 404,
#         "num_of_delays_security": 5,
#         "num_of_delays_weather": 56,
#         "num_of_delays_total": 1745,
#         "minutes_delayed_carrier": 37354.0,
#         "minutes_delayed_late_aircraft": 49549,
#         "minutes_delayed_nas": 13515.0,
#         "minutes_delayed_security": 158,
#         "minutes_delayed_weather": 6693,
#         "minutes_delayed_total": 107269
#     }
# ]
